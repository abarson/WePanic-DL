# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from scipy.stats import linregress

# %%
DATA_PATH = "../wepanic_collated_catalogue.csv"
wepanic_data = pd.read_csv(DATA_PATH)
#wepanic_data = wepanic_data.drop('Unna
wepanic_data
# Out:
#     Unnamed: 0  SUBJECT  TRIAL                   FRAME_PTH  HEART_RATE_BPM  \
# 0            0      1.0      1  frames/S0001/Trial1_frames            64.0
# 1            1      1.0      2  frames/S0001/Trial2_frames            88.0
# 2            2      2.0      1  frames/S0002/Trial1_frames           100.0
# 3            3      2.0      2  frames/S0002/Trial2_frames           128.0
# 4            4      3.0      1  frames/S0003/Trial1_frames            60.0
# 5            5      3.0      2  frames/S0003/Trial2_frames            90.0
# 6            6      4.0      1  frames/S0004/Trial1_frames            56.0
# 7            7      4.0      2  frames/S0004/Trial2_frames            72.0
# 8            8      5.0      1  frames/S0005/Trial1_frames            70.0
# 9            9      5.0      2  frames/S0005/Trial2_frames            76.0
# 10          10      6.0      1  frames/S0006/Trial1_frames            78.0
# 11          11      6.0      2  frames/S0006/Trial2_frames            94.0
# 12          12      7.0      1  frames/S0007/Trial1_frames            81.0
# 13          13      7.0      2  frames/S0007/Trial2_frames           104.0
# 14          14      8.0      1  frames/S0008/Trial1_frames            60.0
# 15          15      8.0      2  frames/S0008/Trial2_frames            84.0
# 16          16      9.0      1  frames/S0009/Trial1_frames            78.0
# 17          17      9.0      2  frames/S0009/Trial2_frames            80.0
# 18          18     10.0      1  frames/S0010/Trial1_frames            66.0
# 19          19     10.0      2  frames/S0010/Trial2_frames            70.0
# 20          20     11.0      1  frames/S0011/Trial1_frames            44.0
# 21          21     11.0      2  frames/S0011/Trial2_frames            84.0
# 22          22     12.0      1  frames/S0012/Trial1_frames            74.0
# 23          23     12.0      2  frames/S0012/Trial2_frames           102.0
# 24          24     13.0      1  frames/S0013/Trial1_frames            80.0
# 25          25     13.0      2  frames/S0013/Trial2_frames            82.0
# 26          26     14.0      1  frames/S0014/Trial1_frames           102.0
# 27          27     14.0      2  frames/S0014/Trial2_frames           122.0
# 28          28     15.0      1  frames/S0015/Trial1_frames            70.0
# 29          29     15.0      2  frames/S0015/Trial2_frames           114.0
# ..         ...      ...    ...                         ...             ...
# 66          66     34.0      1  frames/S0034/Trial1_frames            92.0
# 67          67     34.0      2  frames/S0034/Trial2_frames            88.0
# 68          68     35.0      1  frames/S0035/Trial1_frames            58.0
# 69          69     35.0      2  frames/S0035/Trial2_frames            98.0
# 70          70     36.0      1  frames/S0036/Trial1_frames            70.0
# 71          71     36.0      2  frames/S0036/Trial2_frames            88.0
# 72          72     37.0      1  frames/S0037/Trial1_frames            70.0
# 73          73     37.0      2  frames/S0037/Trial2_frames           112.0
# 74          74     38.0      1  frames/S0038/Trial1_frames            52.0
# 75          75     38.0      2  frames/S0038/Trial2_frames            68.0
# 76          76     39.0      1  frames/S0039/Trial1_frames            62.0
# 77          77     39.0      2  frames/S0039/Trial2_frames            70.0
# 78          78     40.0      1  frames/S0040/Trial1_frames            74.0
# 79          79     40.0      2  frames/S0040/Trial2_frames           100.0
# 80          80     41.0      1  frames/S0041/Trial1_frames            66.0
# 81          81     41.0      2  frames/S0041/Trial2_frames            74.0
# 82          82     42.0      1  frames/S0042/Trial1_frames            62.0
# 83          83     42.0      2  frames/S0042/Trial2_frames            72.0
# 84          84     43.0      1  frames/S0043/Trial1_frames            72.0
# 85          85     43.0      2  frames/S0043/Trial2_frames            98.0
# 86          86     44.0      1  frames/S0044/Trial1_frames            88.0
# 87          87     44.0      2  frames/S0044/Trial2_frames           128.0
# 88          88     45.0      1  frames/S0045/Trial1_frames            82.0
# 89          89     45.0      2  frames/S0045/Trial2_frames           116.0
# 90          90     46.0      1  frames/S0046/Trial1_frames            80.0
# 91          91     46.0      2  frames/S0046/Trial2_frames            92.0
# 92          92     47.0      1  frames/S0047/Trial1_frames            68.0
# 93          93     47.0      2  frames/S0047/Trial2_frames            68.0
# 94          94     48.0      1  frames/S0048/Trial1_frames            58.0
# 95          95     48.0      2  frames/S0048/Trial2_frames            80.0
#
#     RESP_RATE_BR_PM  GOOD
# 0              34.0     0
# 1              48.0     0
# 2              20.0     1
# 3              26.0     1
# 4              20.0     0
# 5              24.0     0
# 6              10.0     1
# 7              18.0     1
# 8              16.0     0
# 9              24.0     0
# 10              7.0     1
# 11             20.0     1
# 12             18.0     0
# 13             30.0     0
# 14             12.0     0
# 15             12.0     1
# 16             22.0     0
# 17             40.0     0
# 18             16.0     0
# 19             22.0     0
# 20             16.0     0
# 21             24.0     0
# 22              8.0     1
# 23             18.0     1
# 24             12.0     1
# 25             16.0     1
# 26             16.0     0
# 27             28.0     0
# 28             24.0     0
# 29             20.0     0
# ..              ...   ...
# 66             14.0     0
# 67             16.0     0
# 68             18.0     0
# 69             22.0     0
# 70             12.0     0
# 71             16.0     0
# 72             11.0     0
# 73             15.0     0
# 74             18.0     1
# 75             40.0     1
# 76             18.0     1
# 77             20.0     1
# 78             18.0     0
# 79             22.0     0
# 80             22.0     0
# 81             22.0     0
# 82             12.0     0
# 83             14.0     0
# 84             16.0     0
# 85             24.0     0
# 86             12.0     0
# 87             18.0     0
# 88             14.0     0
# 89             20.0     0
# 90             10.0     0
# 91             17.0     0
# 92             18.0     1
# 93             12.0     1
# 94             42.0     1
# 95             42.0     1
#
# [96 rows x 7 columns]

# %% [markdown]
# ### data spread and distributions

# %%
hrates = wepanic_data['HEART_RATE_BPM'].values.tolist()
resp_rates = wepanic_data['RESP_RATE_BR_PM'].values.tolist()

useable = wepanic_data[wepanic_data['GOOD'] == 1]
hrates_u = useable['HEART_RATE_BPM'].values.tolist()
resp_rates_u = useable['RESP_RATE_BR_PM'].values.tolist()

# %%
a = 0.75
fig, ax  = plt.subplots(1, figsize=(6.4*a, 4.8*a))

ax.scatter(hrates_u, resp_rates_u, label="$N=%d$" % len(hrates_u))
ax.set_xlabel('Heart rate')
ax.set_ylabel('Respiratory rate')

ax.legend()
plt.savefig('figs/hrate_resprate_spread.pdf')
plt.show()

# %%
fig, ax = plt.subplots(1, figsize=(6.4*a, 4.8*a))

ax.scatter(hrates_u, resp_rates_u, label="real data")

min_resp, max_resp = min(resp_rates_u), max(resp_rates_u)
min_hrate, max_hrate = min(hrates_u), max(hrates_u)

slope, intercept, r_value, p_value, std_err = linregress(hrates_u, resp_rates_u)

def linear(x):
    return slope*x + intercept

X = np.linspace(min_hrate, max_hrate, 100)
#Y = np.linspace(min_resp, max_resp, 100)

#X = [linear(x) + random.uniform(-np.std(X), np.std(X)) for x in X]
#Y = [linear(y) + random.uniform(-np.std(Y), np.std(Y)) for y in Y]
Y = [linear(x) + random.uniform(-np.std(X)/2, np.std(X)) for x in X]

ax.scatter(X, Y, label='randomly generated')

ax.set_xlabel('Heart rate')
ax.set_ylabel('Respiratory Rate')

ax.legend()
plt.savefig('figs/hrate_resprate_spread_withfill.pdf')
plt.show()

# %%
fig, axarr = plt.subplots(1, 2, figsize=(6.4*a, 4.8*a), sharey=True)
n, _, _ = axarr[0].hist(resp_rates_u)
n2, _, _ = axarr[1].hist(hrates_u)

axarr[0].set_ylabel('Count')
axarr[0].set_xlabel('Respiratory rate')
axarr[1].set_xlabel('Heart rate')
plt.savefig('figs/hrate_resprate_counts.pdf')
plt.show()

# %% [markdown]
# ## k-fold experimentation
# * Added stipulations: no subject repetitions in train vs. test

# %%
subject_set = list(set(useable['SUBJECT'].values.tolist()))
n_train = int(0.8*len(subject_set))
n_val = len(subject_set) - n_train
print('got %d distinct subjects in the set of good clips' % len(subject_set))
print('--- %2d samples for training' % n_train)
print('--- %2d samples for validation' % n_val)

# %%
import random

# %%
def fold(df, k=4):
    
    uniques = list(set(df['SUBJECT'].values.tolist()))
    n_val = int(np.ceil(len(uniques)/k))
    
    n_train = len(uniques) - n_val
    #n_val = len(uniques) - n_train
    
u    validated = []
    
    i = 0
    while i < k:
        
        train = validated  + random.sample(uniques, n_train)
        val = list(set(uniques) - set(train))
                
        train_df = df[df['SUBJECT'].isin(train)]
        val_df = df[df['SUBJECT'].isin(val)]
        
        i += 1
        validated.extend(val)
        uniques = list(set(uniques) - set(validated))
                                
        yield train_df.drop('Unnamed: 0', axis=1), val_df.drop('Unnamed: 0', axis=1)

        
train_df, val_df = next(fold(useable))

plt.hist(val_df.HEART_RATE_BPM.values.tolist(), alpha=0.5, label='test')
plt.hist(train_df.HEART_RATE_BPM.values.tolist(), alpha=0.5, label='train')
plt.legend()
plt.show()

# %%
val_df

# %%
14/4

# %%
print('respiratory rate: mean={}, std={}'.format(useable['RESP_RATE_BR_PM'].mean(),
                                                 useable['RESP_RATE_BR_PM'].std()))

print('heart rate: mean={}, std={}'.format(useable['HEART_RATE_BPM'].mean(),
                                           useable['HEART_RATE_BPM'].std()))

resp_rates_u_norm = np.array(resp_rates_u) / np.mean(resp_rates_u)
hrates_u_norm = np.array(hrates_u) / np.mean(hrates_u)

print('respiratory rate, normalized: std={}'.format(np.std(resp_rates_u_norm)))
print('heart rate, normalized: std={}'.format(np.std(hrates_u_norm)))
